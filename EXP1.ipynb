# %%
print("Hello World")
# Out:
# Hello World

# %%
print(20+10)
print(20-10)
print(20*10)
print(20/10)
print(20%10)
# Out:
# 30
# 10
# 200
# 2.0
# 0

# %%
a=10
b=2.2
c='dkte'
print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 10
# 2.2
# dkte
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print('10+20')
print('10-20')
print('10*20')
print('10/20')
print('10%20')
# Out:
# 10+20
# 10-20
# 10*20
# 10/20
# 10%20

# %%
name='swalehin'
print("my name:",name)
# Out:
# my name: swalehin
